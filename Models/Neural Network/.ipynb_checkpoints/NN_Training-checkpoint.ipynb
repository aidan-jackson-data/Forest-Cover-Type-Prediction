# %% [markdown]
# ## This notebook separates the labeled training data into two parts, each with class labels, for rapid testing and evaluation. Reports evaluation metrics at the end of the notebook

# %%
import sklearn as sk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.neural_network import MLPClassifier
from sklearn.metrics import plot_confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# Set the randomizer seed so results are the same each time
np.random.seed(0)

# %%
# import training data from relative filepath
data = pd.read_csv("../../data/train.csv")

# shuffles the data by taking a random sample without replacement
# and sampling 100% of the original dataframe
data = data.sample(frac = 1)

print("The entire training set is " + str(len(data)) + " so, with 80% for training, there will " +
     "be " + str(len(data)*0.8) + " samples in training and " + str(len(data)*0.2) + " samples " +
     "in the test.")
data.head()
# Out:
# The entire training set is 15120 so, with 80% for training, there will be 12096.0 samples in training and 3024.0 samples in the test.
#           Id  Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 4428    4429       2220      18     12                                 0
# 12399  12400       2139     119     10                                 0
# 4647    4648       2292     109     26                               192
# 5953    5954       2345      92     13                                 0
# 2946    2947       1948     347     13                                 0
#
#        Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 4428                                0                              828
# 12399                               0                              933
# 4647                               98                              876
# 5953                                0                              459
# 2946                                0                              180
#
#        Hillshade_9am  Hillshade_Noon  Hillshade_3pm  ...  Soil_Type32  \
# 4428             211             215            140  ...            0
# 12399            237             232            125  ...            0
# 4647             253             201             58  ...            0
# 5953             240             220            109  ...            0
# 2946             194             218            162  ...            0
#
#        Soil_Type33  Soil_Type34  Soil_Type35  Soil_Type36  Soil_Type37  \
# 4428             0            0            0            0            0
# 12399            0            0            0            0            0
# 4647             0            0            0            0            0
# 5953             0            0            0            0            0
# 2946             0            0            0            0            0
#
#        Soil_Type38  Soil_Type39  Soil_Type40  Cover_Type
# 4428             0            0            0           4
# 12399            0            0            0           4
# 4647             0            0            0           4
# 5953             0            0            0           4
# 2946             0            0            0           3
#
# [5 rows x 56 columns]

# %%
# extract random sample of training data except labels and ID column
train_df = data.loc[:, (data.columns != "Cover_Type") & (data.columns != "Id")].iloc[:12096]

# extract labels from training data
train_labels_df = data.iloc[:12096].loc[:, "Cover_Type"]

train_df.head()
# Out:
#        Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 4428        2220      18     12                                 0
# 12399       2139     119     10                                 0
# 4647        2292     109     26                               192
# 5953        2345      92     13                                 0
# 2946        1948     347     13                                 0
#
#        Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 4428                                0                              828
# 12399                               0                              933
# 4647                               98                              876
# 5953                                0                              459
# 2946                                0                              180
#
#        Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 4428             211             215            140
# 12399            237             232            125
# 4647             253             201             58
# 5953             240             220            109
# 2946             194             218            162
#
#        Horizontal_Distance_To_Fire_Points  ...  Soil_Type31  Soil_Type32  \
# 4428                                  351  ...            0            0
# 12399                                 648  ...            0            0
# 4647                                 1429  ...            0            0
# 5953                                  541  ...            0            0
# 2946                                  558  ...            0            0
#
#        Soil_Type33  Soil_Type34  Soil_Type35  Soil_Type36  Soil_Type37  \
# 4428             0            0            0            0            0
# 12399            0            0            0            0            0
# 4647             0            0            0            0            0
# 5953             0            0            0            0            0
# 2946             0            0            0            0            0
#
#        Soil_Type38  Soil_Type39  Soil_Type40
# 4428             0            0            0
# 12399            0            0            0
# 4647             0            0            0
# 5953             0            0            0
# 2946             0            0            0
#
# [5 rows x 54 columns]

# %%
# extract test data except ID and Cover_Type column
test_df = data.loc[:, (data.columns != "Cover_Type") & (data.columns != "Id")].iloc[12096:]

# extract labels data
test_labels_df = data.iloc[12096:].loc[:, "Cover_Type"]

test_df.head()
# Out:
#        Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 5414        2442     302     18                               228
# 6657        3331     104      9                               382
# 3550        2324      92     24                               541
# 5154        2212     316     16                                30
# 10747       2631      90     31                                60
#
#        Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 5414                               70                             1003
# 6657                               70                              960
# 3550                              245                             1416
# 5154                                5                             1613
# 10747                              22                             1423
#
#        Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 5414             166             229            202
# 6657             236             229            124
# 3550             248             196             63
# 5154             176             225            188
# 10747            249             175             31
#
#        Horizontal_Distance_To_Fire_Points  ...  Soil_Type31  Soil_Type32  \
# 5414                                  902  ...            0            0
# 6657                                 1259  ...            0            0
# 3550                                  977  ...            0            0
# 5154                                  242  ...            0            0
# 10747                                1396  ...            0            0
#
#        Soil_Type33  Soil_Type34  Soil_Type35  Soil_Type36  Soil_Type37  \
# 5414             0            0            0            0            0
# 6657             0            0            0            0            0
# 3550             0            0            0            0            0
# 5154             0            0            0            0            0
# 10747            0            0            0            0            0
#
#        Soil_Type38  Soil_Type39  Soil_Type40
# 5414             0            0            0
# 6657             0            1            0
# 3550             0            0            0
# 5154             0            0            0
# 10747            0            0            0
#
# [5 rows x 54 columns]

# %%
## Create current best classifier

# build classifier
classifier = MLPClassifier(early_stopping = True, alpha = 0.0001)

# fit classifier to training data
classifier.fit(train_df, train_labels_df)

# make predictions of test data
predictions = classifier.predict(test_df)

# %%
# generate and print classification report
print(classification_report(test_labels_df, predictions))

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]

for title, normalize in titles_options:
    disp = plot_confusion_matrix(classifier, test_df, test_labels_df,
                                 display_labels= [str(number) for number in range(1, 8)],
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)
    fig = plt.gcf()
    fig.set_size_inches(8,5)

plt.show()

# calculate and print accuracy
print("Overall accuracy: " + 
      str(100*metrics.accuracy_score(test_labels_df, predictions)) + "%")
# Out:
#               precision    recall  f1-score   support
#
#            1       0.65      0.42      0.51       436
#            2       0.52      0.64      0.57       434
#            3       0.64      0.46      0.54       423
#            4       0.87      0.90      0.88       455
#            5       0.80      0.63      0.71       425
#            6       0.52      0.76      0.62       428
#            7       0.79      0.89      0.84       423
#
#     accuracy                           0.67      3024
#    macro avg       0.68      0.67      0.67      3024
# weighted avg       0.69      0.67      0.67      3024
# Overall accuracy: 67.26190476190477%

# %%
## Use grid search to evaluate parameters

# choose variables for grid search
parameters = {"alpha": [0.1, 0.01, 0.001, 0.0001, 0.00001, 0.000001]}

# build classifier
classifier = GridSearchCV(MLPClassifier(early_stopping = True), 
                          param_grid = parameters, cv = 5, 
                          scoring = "accuracy")

# fit classifier to training data
classifier.fit(train_df, train_labels_df)

# make predictions of test data
predictions = classifier.predict(test_df)

# %%
print("Best alpha = ", classifier.best_params_)

# calculate and print accuracy
print("Best accuracy: " + 
      str(100*metrics.accuracy_score(test_labels_df, predictions)) + "%")
# Out:
# Best alpha =  {'alpha': 0.001}
# Best accuracy: 63.32671957671958%

# %%
## Use manual loop to evaluate parameters

for alpha in parameters["alpha"]:
    
    # build classifier
    classifier = MLPClassifier(early_stopping = True, alpha = alpha)

    # fit classifier to training data
    classifier.fit(train_df, train_labels_df)

    # make predictions of test data
    predictions = classifier.predict(test_df)
    
    print("Alpha value: " + str(alpha))
    # calculate and print accuracy
    print("Accuracy: " + 
      str(100*metrics.accuracy_score(test_labels_df, predictions)) + "%")
# Out:
# Alpha value: 0.1
# Accuracy: 63.85582010582011%
# Alpha value: 0.01
# Accuracy: 64.12037037037037%
# Alpha value: 0.001
# Accuracy: 64.12037037037037%
# Alpha value: 0.0001
# Accuracy: 65.0132275132275%
# Alpha value: 1e-05
# Accuracy: 62.632275132275126%
# Alpha value: 1e-06
# Accuracy: 60.085978835978835%
